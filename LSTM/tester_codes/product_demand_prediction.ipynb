# %% [markdown]
# <h1><b>Dependencies</b></h1>

# %%
#TODO: make a new model that predicts the demand of a product
import tensorflow as tf
import pandas as pd
import numpy as np

# %% [markdown]
# <h1><b>Data preprocessing</b></h1>

# %%
product_demand_data = pd.read_csv("../datas\Historical Product Demand.csv")
product_demand_data
# Out:
#          Product_Code Warehouse Product_Category       Date Order_Demand
# 0        Product_0993    Whse_J     Category_028  2012/7/27         100
# 1        Product_0979    Whse_J     Category_028  2012/1/19         500
# 2        Product_0979    Whse_J     Category_028   2012/2/3         500
# 3        Product_0979    Whse_J     Category_028   2012/2/9         500
# 4        Product_0979    Whse_J     Category_028   2012/3/2         500
# ...               ...       ...              ...        ...          ...
# 1048570  Product_1791    Whse_J     Category_006  2016/4/27        1000
# 1048571  Product_1974    Whse_J     Category_006  2016/4/27           1
# 1048572  Product_1787    Whse_J     Category_006  2016/4/28        2500
# 1048573  Product_0901    Whse_J     Category_023  2016/10/7          50
# 1048574  Product_0704    Whse_J     Category_001  2016/6/27           4
#
# [1048575 rows x 5 columns]

# %%
product_demand_data.loc[product_demand_data['Product_Code'] == 'Product_0993']
# Out:
#          Product_Code Warehouse Product_Category       Date Order_Demand
# 0        Product_0993    Whse_J     Category_028  2012/7/27         100
# 34292    Product_0993    Whse_J     Category_028  2012/9/13         300
# 34295    Product_0993    Whse_J     Category_028  2012/9/19         500
# 34298    Product_0993    Whse_J     Category_028  2012/10/9         300
# 85872    Product_0993    Whse_J     Category_028  2012/11/8         200
# ...               ...       ...              ...        ...          ...
# 1044965  Product_0993    Whse_J     Category_028   2016/6/9         200
# 1044966  Product_0993    Whse_J     Category_028  2016/6/13         100
# 1044967  Product_0993    Whse_J     Category_028  2016/6/28         100
# 1044969  Product_0993    Whse_J     Category_028  2016/8/22        1100
# 1045085  Product_0993    Whse_J     Category_028   2016/4/7         100
#
# [312 rows x 5 columns]

# %%
product_code_set = set({})
for i in product_demand_data['Product_Code']:
    product_code_set.add(i)
product_code_set
# Out:
# {'Product_1600',
#  'Product_1326',
#  'Product_1706',
#  'Product_0381',
#  'Product_1581',
#  'Product_0122',
#  'Product_0807',
#  'Product_0931',
#  'Product_1302',
#  'Product_1179',
#  'Product_0456',
#  'Product_1485',
#  'Product_1305',
#  'Product_0197',
#  'Product_0808',
#  'Product_2125',
#  'Product_0920',
#  'Product_0432',
#  'Product_0376',
#  'Product_1759',
#  'Product_0600',
#  'Product_1126',
#  'Product_1764',
#  'Product_0001',
#  'Product_0210',
#  'Product_1193',
#  'Product_1607',
#  'Product_1851',
#  'Product_1202',
#  'Product_0435',
#  'Product_0774',
#  'Product_0719',
#  'Product_1011',
#  'Product_1433',
#  'Product_1827',
#  'Product_1989',
#  'Product_1647',
#  'Product_1970',
#  'Product_0331',
#  'Product_0799',
#  'Product_1790',
#  'Product_1953',
#  'Product_0907',
#  'Product_0709',
#  'Product_0190',
#  'Product_0507',
#  'Product_1134',
#  'Product_1823',
#  'Product_1936',
#  'Product_0566',
#  'Product_1685',
#  'Product_0941',
# ...

# %%
product_code_list = list(product_code_set)
product_code_list.sort(key=lambda x:int(x[-4:]))
product_code_list
# Out:
# ['Product_0001',
#  'Product_0002',
#  'Product_0003',
#  'Product_0004',
#  'Product_0005',
#  'Product_0006',
#  'Product_0007',
#  'Product_0008',
#  'Product_0009',
#  'Product_0010',
#  'Product_0011',
#  'Product_0012',
#  'Product_0013',
#  'Product_0014',
#  'Product_0015',
#  'Product_0016',
#  'Product_0017',
#  'Product_0018',
#  'Product_0019',
#  'Product_0020',
#  'Product_0021',
#  'Product_0022',
#  'Product_0023',
#  'Product_0024',
#  'Product_0025',
#  'Product_0026',
#  'Product_0027',
#  'Product_0028',
#  'Product_0029',
#  'Product_0030',
#  'Product_0031',
#  'Product_0032',
#  'Product_0033',
#  'Product_0034',
#  'Product_0035',
#  'Product_0036',
#  'Product_0037',
#  'Product_0038',
#  'Product_0039',
#  'Product_0040',
#  'Product_0041',
#  'Product_0042',
#  'Product_0043',
#  'Product_0044',
#  'Product_0045',
#  'Product_0046',
#  'Product_0047',
#  'Product_0048',
#  'Product_0049',
#  'Product_0050',
#  'Product_0051',
#  'Product_0052',
# ...

# %%
np.shape(product_code_list)
# Out:
# (2160,)
